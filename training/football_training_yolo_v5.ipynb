# %%
# !pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in d:\football object detection\.venv\lib\site-packages (8.3.93)
# Requirement already satisfied: numpy<=2.1.1,>=1.23.0 in d:\football object detection\.venv\lib\site-packages (from ultralytics) (2.1.1)
# Requirement already satisfied: matplotlib>=3.3.0 in d:\football object detection\.venv\lib\site-packages (from ultralytics) (3.10.1)
# Requirement already satisfied: opencv-python>=4.6.0 in d:\football object detection\.venv\lib\site-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in d:\football object detection\.venv\lib\site-packages (from ultralytics) (11.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in d:\football object detection\.venv\lib\site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in d:\football object detection\.venv\lib\site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in d:\football object detection\.venv\lib\site-packages (from ultralytics) (1.15.2)
# Requirement already satisfied: torch>=1.8.0 in d:\football object detection\.venv\lib\site-packages (from ultralytics) (2.6.0)
# Requirement already satisfied: torchvision>=0.9.0 in d:\football object detection\.venv\lib\site-packages (from ultralytics) (0.21.0)
# Requirement already satisfied: tqdm>=4.64.0 in d:\football object detection\.venv\lib\site-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in d:\football object detection\.venv\lib\site-packages (from ultralytics) (7.0.0)
# Requirement already satisfied: py-cpuinfo in d:\football object detection\.venv\lib\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in d:\football object detection\.venv\lib\site-packages (from ultralytics) (2.2.3)
# Requirement already satisfied: seaborn>=0.11.0 in d:\football object detection\.venv\lib\site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in d:\football object detection\.venv\lib\site-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in d:\football object detection\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in d:\football object detection\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\football object detection\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\football object detection\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in d:\football object detection\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\football object detection\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in d:\football object detection\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\football object detection\.venv\lib\site-packages (from pandas>=1.1.4->ultralytics) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\football object detection\.venv\lib\site-packages (from pandas>=1.1.4->ultralytics) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\football object detection\.venv\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in d:\football object detection\.venv\lib\site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\football object detection\.venv\lib\site-packages (from requests>=2.23.0->ultralytics) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\football object detection\.venv\lib\site-packages (from requests>=2.23.0->ultralytics) (2025.1.31)
# Requirement already satisfied: filelock in d:\football object detection\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in d:\football object detection\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: networkx in d:\football object detection\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in d:\football object detection\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in d:\football object detection\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: setuptools in d:\football object detection\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (77.0.1)
# Requirement already satisfied: sympy==1.13.1 in d:\football object detection\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\football object detection\.venv\lib\site-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: colorama in d:\football object detection\.venv\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: six>=1.5 in d:\football object detection\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\football object detection\.venv\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)

# %%
# !pip install roboflow
# Out:
# Requirement already satisfied: roboflow in d:\football object detection\.venv\lib\site-packages (1.1.58)
# Requirement already satisfied: certifi in d:\football object detection\.venv\lib\site-packages (from roboflow) (2025.1.31)
# Requirement already satisfied: idna==3.7 in d:\football object detection\.venv\lib\site-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in d:\football object detection\.venv\lib\site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\football object detection\.venv\lib\site-packages (from roboflow) (1.4.8)
# Requirement already satisfied: matplotlib in d:\football object detection\.venv\lib\site-packages (from roboflow) (3.10.1)
# Requirement already satisfied: numpy>=1.18.5 in d:\football object detection\.venv\lib\site-packages (from roboflow) (2.1.1)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in d:\football object detection\.venv\lib\site-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in d:\football object detection\.venv\lib\site-packages (from roboflow) (11.1.0)
# Requirement already satisfied: pillow-heif>=0.18.0 in d:\football object detection\.venv\lib\site-packages (from roboflow) (0.22.0)
# Requirement already satisfied: python-dateutil in d:\football object detection\.venv\lib\site-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in d:\football object detection\.venv\lib\site-packages (from roboflow) (1.0.1)
# Requirement already satisfied: requests in d:\football object detection\.venv\lib\site-packages (from roboflow) (2.32.3)
# Requirement already satisfied: six in d:\football object detection\.venv\lib\site-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in d:\football object detection\.venv\lib\site-packages (from roboflow) (2.3.0)
# Requirement already satisfied: tqdm>=4.41.0 in d:\football object detection\.venv\lib\site-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in d:\football object detection\.venv\lib\site-packages (from roboflow) (6.0.2)
# Requirement already satisfied: requests-toolbelt in d:\football object detection\.venv\lib\site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in d:\football object detection\.venv\lib\site-packages (from roboflow) (1.2.0)
# Requirement already satisfied: colorama in d:\football object detection\.venv\lib\site-packages (from tqdm>=4.41.0->roboflow) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in d:\football object detection\.venv\lib\site-packages (from matplotlib->roboflow) (1.3.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\football object detection\.venv\lib\site-packages (from matplotlib->roboflow) (4.56.0)
# Requirement already satisfied: packaging>=20.0 in d:\football object detection\.venv\lib\site-packages (from matplotlib->roboflow) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\football object detection\.venv\lib\site-packages (from matplotlib->roboflow) (3.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\football object detection\.venv\lib\site-packages (from requests->roboflow) (3.4.1)

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="BqbMDXbzREaQIrWaLmo7")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
dataset.location
# Out:
# 'd:\\football object detection\\.venv\\training\\football-players-detection-1'

# %%
import shutil
shutil.move('football-players-detection-1/train',
            'football-players-detection-1/football-players-detection-1/train'
            )

shutil.move('football-players-detection-1/test',
            'football-players-detection-1/football-players-detection-1/test'
            )

shutil.move('football-players-detection-1/valid',
            'football-players-detection-1/football-players-detection-1/valid'
            )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\shutil.py:856, in move(src, dst, copy_function)
#     855 try:
# --> 856     os.rename(src, real_dst)
#     857 except OSError:
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'football-players-detection-1/train' -> 'football-players-detection-1/football-players-detection-1/train\\train'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 import shutil
# ----> 2 shutil.move('football-players-detection-1/train',
#       3             'football-players-detection-1/football-players-detection-1/train'
#       4             )
#       6 shutil.move('football-players-detection-1/test',
#       7             'football-players-detection-1/football-players-detection-1/test'
#       8             )
#      10 shutil.move('football-players-detection-1/valid',
#      11             'football-players-detection-1/football-players-detection-1/valid'
#      12             )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\shutil.py:876, in move(src, dst, copy_function)
#     874         rmtree(src)
#     875     else:
# --> 876         copy_function(src, real_dst)
#     877         os.unlink(src)
#     878 return real_dst
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\shutil.py:453, in copy2(src, dst, follow_symlinks)
#     451     flags |= _winapi.COPY_FILE_COPY_SYMLINK
#     452 try:
# --> 453     _winapi.CopyFile2(src_, dst_, flags)
#     454     return dst
#     455 except OSError as exc:
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified

# %% [markdown]
# # Training

# %%
# !yolo task=detect mode=train model=yolov5x.pt data="{dataset.location}/data.yaml" epochs=100 batch=2 imgsz=640 device=0
# Out:
# PRO TIP 💡 Replace 'model=yolov5x.pt' with new 'model=yolov5xu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# Ultralytics 8.3.93 🚀 Python-3.13.2 torch-2.6.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3050 6GB Laptop GPU, 6144MiB)
# engine\trainer: task=detect, mode=train, model=yolov5x.pt, data=d:\football object detection\.venv\training\football-players-detection-1/data.yaml, epochs=100, time=None, patience=100, batch=2, imgsz=640, save=True, save_period=-1, cache=False, device=0, workers=8, project=None, name=train9, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs\detect\train9
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      8800  ultralytics.nn.modules.conv.Conv             [3, 80, 6, 2, 2]
#   1                  -1  1    115520  ultralytics.nn.modules.conv.Conv             [80, 160, 3, 2]
#   2                  -1  4    309120  ultralytics.nn.modules.block.C3              [160, 160, 4]
#   3                  -1  1    461440  ultralytics.nn.modules.conv.Conv             [160, 320, 3, 2]
#   4                  -1  8   2259200  ultralytics.nn.modules.block.C3              [320, 320, 8]
#   5                  -1  1   1844480  ultralytics.nn.modules.conv.Conv             [320, 640, 3, 2]
#   6                  -1 12  13125120  ultralytics.nn.modules.block.C3              [640, 640, 12]
#   7                  -1  1   7375360  ultralytics.nn.modules.conv.Conv             [640, 1280, 3, 2]
#   8                  -1  4  19676160  ultralytics.nn.modules.block.C3              [1280, 1280, 4]
#   9                  -1  1   4099840  ultralytics.nn.modules.block.SPPF            [1280, 1280, 5]
#  10                  -1  1    820480  ultralytics.nn.modules.conv.Conv             [1280, 640, 1, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  4   5332480  ultralytics.nn.modules.block.C3              [1280, 640, 4, False]
#  14                  -1  1    205440  ultralytics.nn.modules.conv.Conv             [640, 320, 1, 1]
#  15                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  16             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  17                  -1  4   1335040  ultralytics.nn.modules.block.C3              [640, 320, 4, False]
#  18                  -1  1    922240  ultralytics.nn.modules.conv.Conv             [320, 320, 3, 2]
#  19            [-1, 14]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  20                  -1  4   4922880  ultralytics.nn.modules.block.C3              [640, 640, 4, False]
#  21                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#  22            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  23                  -1  4  19676160  ultralytics.nn.modules.block.C3              [1280, 1280, 4, False]
#  24        [17, 20, 23]  1  11025820  ultralytics.nn.modules.head.Detect           [4, [320, 640, 1280]]
# YOLOv5x summary: 285 layers, 97,203,260 parameters, 97,203,244 gradients, 246.9 GFLOPs
#
# Transferred 817/823 items from pretrained weights
# Freezing layer 'model.24.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Scanning D:\football object detection\.venv\training\football-players-detection-1\football-players-detection-1\train\labels.cache... 612 images, 0 backgrounds, 0 corrupt: 100%|██████████| 612/612 [00:00<?, ?it/s]
# train: Scanning D:\football object detection\.venv\training\football-players-detection-1\football-players-detection-1\train\labels.cache... 612 images, 0 backgrounds, 0 corrupt: 100%|██████████| 612/612 [00:00<?, ?it/s]
#
# val: Scanning D:\football object detection\.venv\training\football-players-detection-1\football-players-detection-1\valid\labels.cache... 38 images, 0 backgrounds, 0 corrupt: 100%|██████████| 38/38 [00:00<?, ?it/s]
# val: Scanning D:\football object detection\.venv\training\football-players-detection-1\football-players-detection-1\valid\labels.cache... 38 images, 0 backgrounds, 0 corrupt: 100%|██████████| 38/38 [00:00<?, ?it/s]
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#     from multiprocessing.spawn import spawn_main; spawn_main(parent_pid=3956, pipe_handle=1572)
#                                                   ~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\multiprocessing\spawn.py", line 122, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\multiprocessing\spawn.py", line 132, in _main
#     self = reduction.pickle.load(from_parent)
#   File "d:\football object detection\.venv\Lib\site-packages\torch\__init__.py", line 274, in <module>
#     _load_dll_libraries()
#     ~~~~~~~~~~~~~~~~~~~^^
#   File "d:\football object detection\.venv\Lib\site-packages\torch\__init__.py", line 257, in _load_dll_libraries
#     raise err
# OSError: [WinError 1455] The paging file is too small for this operation to complete. Error loading "d:\football object detection\.venv\Lib\site-packages\torch\lib\cupti64_2022.3.0.dll" or one of its dependencies.
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#     from multiprocessing.spawn import spawn_main; spawn_main(parent_pid=3956, pipe_handle=1432)
#                                                   ~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\multiprocessing\spawn.py", line 122, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\multiprocessing\spawn.py", line 132, in _main
#     self = reduction.pickle.load(from_parent)
#   File "d:\football object detection\.venv\Lib\site-packages\torch\__init__.py", line 274, in <module>
#     _load_dll_libraries()
#     ~~~~~~~~~~~~~~~~~~~^^
#   File "d:\football object detection\.venv\Lib\site-packages\torch\__init__.py", line 257, in _load_dll_libraries
#     raise err
# OSError: [WinError 1455] The paging file is too small for this operation to complete. Error loading "d:\football object detection\.venv\Lib\site-packages\torch\lib\c10.dll" or one of its dependencies.
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#     from multiprocessing.spawn import spawn_main; spawn_main(parent_pid=3956, pipe_handle=2128)
#                                                   ~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\multiprocessing\spawn.py", line 122, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\multiprocessing\spawn.py", line 132, in _main
#     self = reduction.pickle.load(from_parent)
#   File "d:\football object detection\.venv\Lib\site-packages\torch\__init__.py", line 2046, in <module>
#     _C._initExtension(_manager_path())
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
# MemoryError
#   File "<string>", line 1, in <module>
#     from multiprocessing.spawn import spawn_main; spawn_main(parent_pid=3956, pipe_handle=2208)
#                                                   ~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\multiprocessing\spawn.py", line 122, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\multiprocessing\spawn.py", line 132, in _main
#     self = reduction.pickle.load(from_parent)
#   File "d:\football object detection\.venv\Lib\site-packages\torch\__init__.py", line 2046, in <module>
#     _C._initExtension(_manager_path())
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
# MemoryError
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#     from multiprocessing.spawn import spawn_main; spawn_main(parent_pid=3956, pipe_handle=1296)
#                                                   ~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\multiprocessing\spawn.py", line 122, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\multiprocessing\spawn.py", line 132, in _main
#     self = reduction.pickle.load(from_parent)
#   File "d:\football object detection\.venv\Lib\site-packages\torch\__init__.py", line 274, in <module>
#     _load_dll_libraries()
#     ~~~~~~~~~~~~~~~~~~~^^
#   File "d:\football object detection\.venv\Lib\site-packages\torch\__init__.py", line 257, in _load_dll_libraries
#     raise err
# OSError: [WinError 1114] A dynamic link library (DLL) initialization routine failed. Error loading "d:\football object detection\.venv\Lib\site-packages\torch\lib\shm.dll" or one of its dependencies.
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#     from multiprocessing.spawn import spawn_main; spawn_main(parent_pid=3956, pipe_handle=1416)
#                                                   ~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\multiprocessing\spawn.py", line 122, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\multiprocessing\spawn.py", line 132, in _main
#     self = reduction.pickle.load(from_parent)
#   File "d:\football object detection\.venv\Lib\site-packages\torch\__init__.py", line 274, in <module>
#     _load_dll_libraries()
#     ~~~~~~~~~~~~~~~~~~~^^
#   File "d:\football object detection\.venv\Lib\site-packages\torch\__init__.py", line 257, in _load_dll_libraries
#     raise err
# OSError: [WinError 1455] The paging file is too small for this operation to complete. Error loading "d:\football object detection\.venv\Lib\site-packages\torch\lib\cufft64_10.dll" or one of its dependencies.
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#     from multiprocessing.spawn import spawn_main; spawn_main(parent_pid=3956, pipe_handle=1928)
#                                                   ~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\multiprocessing\spawn.py", line 122, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\multiprocessing\spawn.py", line 132, in _main
#     self = reduction.pickle.load(from_parent)
#   File "d:\football object detection\.venv\Lib\site-packages\torch\__init__.py", line 274, in <module>
#     _load_dll_libraries()
#     ~~~~~~~~~~~~~~~~~~~^^
#   File "d:\football object detection\.venv\Lib\site-packages\torch\__init__.py", line 257, in _load_dll_libraries
#     raise err
# OSError: [WinError 1455] The paging file is too small for this operation to complete. Error loading "d:\football object detection\.venv\Lib\site-packages\torch\lib\cufft64_10.dll" or one of its dependencies.
#   File "<string>", line 1, in <module>
#     from multiprocessing.spawn import spawn_main; spawn_main(parent_pid=3956, pipe_handle=1516)
#                                                   ~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\multiprocessing\spawn.py", line 122, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\multiprocessing\spawn.py", line 132, in _main
#     self = reduction.pickle.load(from_parent)
#   File "d:\football object detection\.venv\Lib\site-packages\torch\__init__.py", line 274, in <module>
#     _load_dll_libraries()
#     ~~~~~~~~~~~~~~~~~~~^^
#   File "d:\football object detection\.venv\Lib\site-packages\torch\__init__.py", line 257, in _load_dll_libraries
#     raise err
# OSError: [WinError 1455] The paging file is too small for this operation to complete. Error loading "d:\football object detection\.venv\Lib\site-packages\torch\lib\cufft64_10.dll" or one of its dependencies.
#   File "<string>", line 1, in <module>
#     from multiprocessing.spawn import spawn_main; spawn_main(parent_pid=3956, pipe_handle=2552)
#                                                   ~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\multiprocessing\spawn.py", line 122, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\multiprocessing\spawn.py", line 132, in _main
#     self = reduction.pickle.load(from_parent)
#   File "d:\football object detection\.venv\Lib\site-packages\torch\__init__.py", line 274, in <module>
#     _load_dll_libraries()
#     ~~~~~~~~~~~~~~~~~~~^^
#   File "d:\football object detection\.venv\Lib\site-packages\torch\__init__.py", line 257, in _load_dll_libraries
#     raise err
# OSError: [WinError 1455] The paging file is too small for this operation to complete. Error loading "d:\football object detection\.venv\Lib\site-packages\torch\lib\cufft64_10.dll" or one of its dependencies.
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#     from multiprocessing.spawn import spawn_main; spawn_main(parent_pid=3956, pipe_handle=1788)
#                                                   ~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\multiprocessing\spawn.py", line 122, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\multiprocessing\spawn.py", line 132, in _main
#     self = reduction.pickle.load(from_parent)
#   File "d:\football object detection\.venv\Lib\site-packages\torch\__init__.py", line 274, in <module>
#     _load_dll_libraries()
#     ~~~~~~~~~~~~~~~~~~~^^
#   File "d:\football object detection\.venv\Lib\site-packages\torch\__init__.py", line 257, in _load_dll_libraries
#     raise err
# OSError: [WinError 1455] The paging file is too small for this operation to complete. Error loading "d:\football object detection\.venv\Lib\site-packages\torch\lib\curand64_10.dll" or one of its dependencies.
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "d:\football object detection\.venv\Scripts\yolo.exe\__main__.py", line 7, in <module>
#     sys.exit(entrypoint())
#              ~~~~~~~~~~^^
#   File "d:\football object detection\.venv\Lib\site-packages\ultralytics\cfg\__init__.py", line 987, in entrypoint
#     getattr(model, mode)(**overrides)  # default args from model
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^
#   File "d:\football object detection\.venv\Lib\site-packages\ultralytics\engine\model.py", line 791, in train
#     self.trainer.train()
#     ~~~~~~~~~~~~~~~~~~^^
#   File "d:\football object detection\.venv\Lib\site-packages\ultralytics\engine\trainer.py", line 211, in train
#     self._do_train(world_size)
#     ~~~~~~~~~~~~~~^^^^^^^^^^^^
#   File "d:\football object detection\.venv\Lib\site-packages\ultralytics\engine\trainer.py", line 326, in _do_train
#     self._setup_train(world_size)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
#   File "d:\football object detection\.venv\Lib\site-packages\ultralytics\engine\trainer.py", line 299, in _setup_train
#     self.ema = ModelEMA(self.model)
#                ~~~~~~~~^^^^^^^^^^^^
#   File "d:\football object detection\.venv\Lib\site-packages\ultralytics\utils\torch_utils.py", line 638, in __init__
#     self.ema = deepcopy(de_parallel(model)).eval()  # FP32 EMA
#                ~~~~~~~~^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\copy.py", line 163, in deepcopy
#     y = _reconstruct(x, memo, *rv)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\copy.py", line 260, in _reconstruct
#     state = deepcopy(state, memo)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\copy.py", line 137, in deepcopy
#     y = copier(x, memo)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\copy.py", line 222, in _deepcopy_dict
#     y[deepcopy(key, memo)] = deepcopy(value, memo)
#                              ~~~~~~~~^^^^^^^^^^^^^
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\copy.py", line 137, in deepcopy
#     y = copier(x, memo)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\copy.py", line 222, in _deepcopy_dict
#     y[deepcopy(key, memo)] = deepcopy(value, memo)
#                              ~~~~~~~~^^^^^^^^^^^^^
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\copy.py", line 163, in deepcopy
#     y = _reconstruct(x, memo, *rv)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\copy.py", line 260, in _reconstruct
#     state = deepcopy(state, memo)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\copy.py", line 137, in deepcopy
#     y = copier(x, memo)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\copy.py", line 222, in _deepcopy_dict
#     y[deepcopy(key, memo)] = deepcopy(value, memo)
#                              ~~~~~~~~^^^^^^^^^^^^^
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\copy.py", line 137, in deepcopy
#     y = copier(x, memo)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\copy.py", line 222, in _deepcopy_dict
#     y[deepcopy(key, memo)] = deepcopy(value, memo)
#                              ~~~~~~~~^^^^^^^^^^^^^
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\copy.py", line 163, in deepcopy
#     y = _reconstruct(x, memo, *rv)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\copy.py", line 260, in _reconstruct
#     state = deepcopy(state, memo)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\copy.py", line 137, in deepcopy
#     y = copier(x, memo)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\copy.py", line 222, in _deepcopy_dict
#     y[deepcopy(key, memo)] = deepcopy(value, memo)
#                              ~~~~~~~~^^^^^^^^^^^^^
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\copy.py", line 137, in deepcopy
#     y = copier(x, memo)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\copy.py", line 222, in _deepcopy_dict
#     y[deepcopy(key, memo)] = deepcopy(value, memo)
#                              ~~~~~~~~^^^^^^^^^^^^^
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\copy.py", line 163, in deepcopy
#     y = _reconstruct(x, memo, *rv)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\copy.py", line 260, in _reconstruct
#     state = deepcopy(state, memo)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\copy.py", line 137, in deepcopy
#     y = copier(x, memo)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\copy.py", line 222, in _deepcopy_dict
#     y[deepcopy(key, memo)] = deepcopy(value, memo)
#                              ~~~~~~~~^^^^^^^^^^^^^
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\copy.py", line 137, in deepcopy
#     y = copier(x, memo)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\copy.py", line 222, in _deepcopy_dict
#     y[deepcopy(key, memo)] = deepcopy(value, memo)
#                              ~~~~~~~~^^^^^^^^^^^^^
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\copy.py", line 163, in deepcopy
#     y = _reconstruct(x, memo, *rv)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\copy.py", line 260, in _reconstruct
#     state = deepcopy(state, memo)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\copy.py", line 137, in deepcopy
#     y = copier(x, memo)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\copy.py", line 222, in _deepcopy_dict
#     y[deepcopy(key, memo)] = deepcopy(value, memo)
#                              ~~~~~~~~^^^^^^^^^^^^^
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\copy.py", line 137, in deepcopy
#     y = copier(x, memo)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\copy.py", line 222, in _deepcopy_dict
#     y[deepcopy(key, memo)] = deepcopy(value, memo)
#                              ~~~~~~~~^^^^^^^^^^^^^
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\copy.py", line 163, in deepcopy
#     y = _reconstruct(x, memo, *rv)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\copy.py", line 260, in _reconstruct
#     state = deepcopy(state, memo)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\copy.py", line 137, in deepcopy
#     y = copier(x, memo)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\copy.py", line 222, in _deepcopy_dict
#     y[deepcopy(key, memo)] = deepcopy(value, memo)
#                              ~~~~~~~~^^^^^^^^^^^^^
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\copy.py", line 137, in deepcopy
#     y = copier(x, memo)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\copy.py", line 222, in _deepcopy_dict
#     y[deepcopy(key, memo)] = deepcopy(value, memo)
#                              ~~~~~~~~^^^^^^^^^^^^^
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\copy.py", line 163, in deepcopy
#     y = _reconstruct(x, memo, *rv)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\copy.py", line 260, in _reconstruct
#     state = deepcopy(state, memo)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\copy.py", line 137, in deepcopy
#     y = copier(x, memo)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\copy.py", line 222, in _deepcopy_dict
#     y[deepcopy(key, memo)] = deepcopy(value, memo)
#                              ~~~~~~~~^^^^^^^^^^^^^
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\copy.py", line 137, in deepcopy
#     y = copier(x, memo)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\copy.py", line 222, in _deepcopy_dict
#     y[deepcopy(key, memo)] = deepcopy(value, memo)
#                              ~~~~~~~~^^^^^^^^^^^^^
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\copy.py", line 144, in deepcopy
#     y = copier(memo)
#   File "d:\football object detection\.venv\Lib\site-packages\torch\nn\parameter.py", line 68, in __deepcopy__
#     self.data.clone(memory_format=torch.preserve_format), self.requires_grad
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 16.00 MiB. GPU 0 has a total capacity of 6.00 GiB of which 4.26 GiB is free. Of the allocated memory 741.19 MiB is allocated by PyTorch, and 20.81 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
import torch

# %%
print(torch.cuda.is_available())
print(torch.cuda.device_count())
print(torch.cuda.get_device_name(0))
print(torch.cuda.current_device())
# Out:
# False
# 0
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[8], line 3
#       1 print(torch.cuda.is_available())
#       2 print(torch.cuda.device_count())
# ----> 3 print(torch.cuda.get_device_name(0))
#       4 print(torch.cuda.current_device())
#
# File d:\football object detection\.venv\Lib\site-packages\torch\cuda\__init__.py:491, in get_device_name(device)
#     479 def get_device_name(device: Optional[_device_t] = None) -> str:
#     480     r"""Get the name of a device.
#     481
#     482     Args:
#    (...)    489         str: the name of the device
#     490     """
# --> 491     return get_device_properties(device).name
#
# File d:\football object detection\.venv\Lib\site-packages\torch\cuda\__init__.py:523, in get_device_properties(device)
#     511 def get_device_properties(device: Optional[_device_t] = None) -> _CudaDeviceProperties:
#     512     r"""Get the properties of a device.
#     513
#     514     Args:
#    (...)    521         _CudaDeviceProperties: the properties of the device
#     522     """
# --> 523     _lazy_init()  # will define _get_device_properties
#     524     device = _get_device_index(device, optional=True)
#     525     if device < 0 or device >= device_count():
#
# File d:\football object detection\.venv\Lib\site-packages\torch\cuda\__init__.py:310, in _lazy_init()
#     305     raise RuntimeError(
#     306         "Cannot re-initialize CUDA in forked subprocess. To use CUDA with "
#     307         "multiprocessing, you must use the 'spawn' start method"
#     308     )
#     309 if not hasattr(torch._C, "_cuda_getDeviceCount"):
# --> 310     raise AssertionError("Torch not compiled with CUDA enabled")
#     311 if _cudart is None:
#     312     raise AssertionError(
#     313         "libcudart functions unavailable. It looks like you have a broken build?"
#     314     )
#
# AssertionError: Torch not compiled with CUDA enabled
